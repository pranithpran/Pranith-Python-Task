# %%
num = int(input("Enter any number"))
for i in range(1,11):
    print(f"{num} * {i} = {num*i}")
# Out:
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40

# %%
print(i)
# Out:
# 70

# %%
num = int(input("enter a number"))
for i in range(1,11):
    print(f"{num} + {i} = {num+i}")
# Out:
# 4 + 1 = 5
# 4 + 2 = 6
# 4 + 3 = 7
# 4 + 4 = 8
# 4 + 5 = 9
# 4 + 6 = 10
# 4 + 7 = 11
# 4 + 8 = 12
# 4 + 9 = 13
# 4 + 10 = 14

# %%
num = int(input("enter any number"))
for i in range(1,11):
    print(f"{num} - {i} = {num-i}")
# Out:
# 17 - 1 = 16
# 17 - 2 = 15
# 17 - 3 = 14
# 17 - 4 = 13
# 17 - 5 = 12
# 17 - 6 = 11
# 17 - 7 = 10
# 17 - 8 = 9
# 17 - 9 = 8
# 17 - 10 = 7
